# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random


sign = ('stone', 'paper', 'scissors')

maximum = 5

towin = 3

x = random.choice(sign)
pcwins = 0

y = 0
pwins = 0
tie = 0
mx = 0
while y != 'stone' and y != 'paper' and y !='scissors':
    if pcwins == towin or pwins == towin:
        print("Limite de vitorias!!")
        break
    if mx == 5:
        print("Empatou")
        break
    mx += 1
    y = input("Choose one available option, stone, paper or scissors: ")
    x = random.choice(sign)
    print("Computador jogou {}".format(x))
    print("Jogador jogou {}".format(y))


        
    if x == 'stone':
        if y == 'stone':
            tie += 1
            print(0)
            y = 0                
        elif y == 'scissors':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'paper':
            pwins += 1
            print(2)
            y = 0
    elif x == 'paper': 
        if y == 'stone':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'scissors':
            pwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            tie += 1
            print(0)
            y = 0
    elif x == 'scissors':
        if y == 'scissors':
            tie += 1
            print(0)
            y = 0
        elif y == 'stone':
            pwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            pcwins += 1
            print(1)
            y = 0

if pcwins == towin:
    print("Computador ganhou!!!!")
elif pwins == towin:
    print("Jogador Ganhou!!")
    
    
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Choose one available option, stone, paper or scissors: paper
# Computador jogou paper
# Jogador jogou paper
# Choose one available option, stone, paper or scissors: paper
# Computador jogou stone
# Jogador jogou paper
# 2
# Choose one available option, stone, paper or scissors: paper
# Computador jogou paper
# Jogador jogou paper
# 0
# Choose one available option, stone, paper or scissors: paper
# Computador jogou paper
# Jogador jogou paper
# 0
# Choose one available option, stone, paper or scissors: paper
# Computador jogou stone
# Jogador jogou paper
# 2
# Empatou

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
import random


sign = ('stone', 'paper', 'scissors','lizard','spock')

maximum = 10

towin = 6

x = random.choice(sign)
pcwins = 0

y = 0
pwins = 0
tie = 0
mx = 0
while y != 'stone' and y != 'paper' and y != 'scissors' and y != 'lizard' and y != 'spock':
    if pcwins == towin or pwins == towin:
        print("Limite de vitorias!!")
        break
    if mx == 10:
        print("Empatou")
        break
    mx += 1
    y = input("Choose one available option, stone, paper, scissors, lizard or spock: ")
    x = random.choice(sign)
    print("Computador jogou {}".format(x))
    print("Jogador jogou {}".format(y))


        
    if x == 'stone':
        if y == 'stone':
            tie += 1
            print(0)
            y = 0                
        elif y == 'scissors':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'paper':
            pwins += 1
            print(2)
            y = 0
        elif y == 'lizar':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'spock':
            pwins += 1
            print(2)
            y = 0
    elif x == 'paper': 
        if y == 'stone':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'scissors':
            pwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            tie += 1
            print(0)
            y = 0
        elif y == 'lizar':
            pwins += 1
            print(1)
            y = 0
        elif y == 'spock':
            pcwins += 1
            print(2)
            y = 0
    elif x == 'lizard':
        if y == 'scissors':
            pwins += 1
            print(0)
            y = 0
        elif y == 'stone':
            pwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'lizar':
            tie += 1
            print(1)
            y = 0
        elif y == 'spock':
            pcwins += 1
            print(2)
            y = 0

    elif x == 'scissors':
        if y == 'scissors':
            tie += 1
            print(0)
            y = 0
        elif y == 'stone':
            pwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'lizar':
            pcwins += 1
            print(1)
            y = 0
        elif y == 'spock':
            pwins += 1
            print(2)
            y = 0
    elif x == 'spock':
        if y == 'scissors':
            pcwins += 1
            print(0)
            y = 0
        elif y == 'stone':
            pcwins += 1
            print(2)
            y = 0
        elif y == 'paper':
            pwins += 1
            print(1)
            y = 0
        elif y == 'lizar':
            pwins += 1
            print(1)
            y = 0
        elif y == 'spock':
            tie += 1
            print(2)
            y = 0
if pcwins == towin:
    print("Computador ganhou!!!!")
elif pwins == towin:
    print("Jogador Ganhou!!")
    

# Assign a list of 5 possible options.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

    
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou lizard
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou scissors
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou paper
# Jogador jogou paper
# 0
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou scissors
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou stone
# Jogador jogou paper
# 2
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou spock
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou scissors
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou scissors
# Jogador jogou paper
# 1
# Escolha uma opção disponível, pedra, papel, tesoura, lagarto ou spock:paper
# Computador jogou lizard
# Jogador jogou paper
# 1
# Limite de vitorias!!
# Computador ganhou!!!!
